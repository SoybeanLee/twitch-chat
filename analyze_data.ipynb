# %%
import pandas as pd
# make the panda cells wider
pd.options.display.max_colwidth = None

# %%
video_id = '2490741688'
chat_tsv_path = f'data/{video_id}/{video_id}_chat.tsv'
transcript_tsv_path = f'data/{video_id}/{video_id}_transcript.tsv'

chat_df = pd.read_csv(chat_tsv_path, sep='\t', header=0, index_col=None)
transcript_df = pd.read_csv(transcript_tsv_path, sep='\t', header=0, index_col=None)

# %%
f'{video_id} chat rows: {len(chat_df):,} transcript rows: {len(transcript_df):,}'
# Out:
# '2490741688 chat rows: 14,479 transcript rows: 2,585'

# %%
chat_df.head(20)
# Out:
#        time            author              message
# 0   0:00:04       KittyKingTV                 Live
# 1   0:00:06       KittyKingTV                  Pog
# 2   0:00:17          Kman2see                 LIVE
# 3   0:00:18          Kman2see                  Pog
# 4   0:00:20         guactoast             Pog LIVE
# 5   0:00:20       CrxstalStar                  yo-
# 6   0:00:21        Chinstero_                 PogU
# 7   0:00:22       CrxstalStar  WhistletopConductor
# 8   0:00:24         MHanDaMan                  POG
# 9   0:00:25          Kman2see                FRIST
# 10  0:00:26          Kman2see                  Pog
# 11  0:00:26       AngusGuitar             Pog LIVE
# 12  0:00:28      LordFartamor             hi clint
# 13  0:00:30              2poz                  POG
# 14  0:00:30    scriptwriting1               PagMan
# 15  0:00:31      SubparTrassh                heyyy
# 16  0:00:31      JungleRammus                  Pog
# ...

# %%
transcript_df.head(20)
# Out:
#             time  \
# 0   00:00:00.000
# 1   00:00:30.000
# 2   00:00:42.000
# 3   00:00:54.720
# 4   00:01:00.000
# 5   00:01:14.000
# 6   00:01:16.000
# 7   00:01:28.000
# 8   00:01:30.000
# 9   00:01:34.000
# 10  00:01:52.000
# 11  00:02:00.000
# 12  00:02:05.440
# 13  00:02:10.000
# 14  00:02:16.000
# 15  00:02:31.680
# 16  00:02:35.360
# 17  00:02:48.960
# 18  00:02:58.960
# 19  00:03:06.960
#
#                                                                                                 text
# 0                                                                                                You
# 1                                                                                                  I
# 2                                                                                           Hey chat
# 3                                                            Notifications off. What does that mean?
# ...
